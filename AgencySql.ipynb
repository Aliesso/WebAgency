-- %% [markdown]
-- # [K102AgencyDB]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [K102AgencyDB]    Script Date: 9.02.2021 11:42:08 ******/
CREATE DATABASE [K102AgencyDB]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'K102AgencyDB', FILENAME = N'D:\SQL\MSSQL14.ALIESSOMSSQL\MSSQL\DATA\K102AgencyDB.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'K102AgencyDB_log', FILENAME = N'D:\SQL\MSSQL14.ALIESSOMSSQL\MSSQL\DATA\K102AgencyDB_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
GO
ALTER DATABASE [K102AgencyDB] SET COMPATIBILITY_LEVEL = 140
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [K102AgencyDB].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [K102AgencyDB] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [K102AgencyDB] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [K102AgencyDB] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [K102AgencyDB] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [K102AgencyDB] SET ARITHABORT OFF 
GO
ALTER DATABASE [K102AgencyDB] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [K102AgencyDB] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [K102AgencyDB] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [K102AgencyDB] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [K102AgencyDB] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [K102AgencyDB] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [K102AgencyDB] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [K102AgencyDB] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [K102AgencyDB] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [K102AgencyDB] SET  ENABLE_BROKER 
GO
ALTER DATABASE [K102AgencyDB] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [K102AgencyDB] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [K102AgencyDB] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [K102AgencyDB] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [K102AgencyDB] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [K102AgencyDB] SET READ_COMMITTED_SNAPSHOT ON 
GO
ALTER DATABASE [K102AgencyDB] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [K102AgencyDB] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [K102AgencyDB] SET  MULTI_USER 
GO
ALTER DATABASE [K102AgencyDB] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [K102AgencyDB] SET DB_CHAINING OFF 
GO
ALTER DATABASE [K102AgencyDB] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [K102AgencyDB] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [K102AgencyDB] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [K102AgencyDB] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[__EFMigrationsHistory]

-- %%
USE [K102AgencyDB]
GO

-- %%
/****** Object:  Table [dbo].[__EFMigrationsHistory]    Script Date: 9.02.2021 11:42:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[__EFMigrationsHistory](
	[MigrationId] [nvarchar](150) NOT NULL,
	[ProductVersion] [nvarchar](32) NOT NULL,
 CONSTRAINT [PK___EFMigrationsHistory] PRIMARY KEY CLUSTERED 
(
	[MigrationId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Blogs]

-- %%
/****** Object:  Table [dbo].[Blogs]    Script Date: 9.02.2021 11:42:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Blogs](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Header] [nvarchar](max) NULL,
	[Description] [nvarchar](max) NULL,
	[PublishingDate] [datetime2](7) NOT NULL,
	[PhotoUrl] [nvarchar](max) NULL,
 CONSTRAINT [PK_Blogs] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Brands]

-- %%
/****** Object:  Table [dbo].[Brands]    Script Date: 9.02.2021 11:42:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Brands](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[PhotoUrl] [nvarchar](max) NULL,
 CONSTRAINT [PK_Brands] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Portfolios]

-- %%
/****** Object:  Table [dbo].[Portfolios]    Script Date: 9.02.2021 11:42:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Portfolios](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Header] [nvarchar](max) NULL,
	[Description] [nvarchar](max) NULL,
	[PhotoUrl] [nvarchar](max) NULL,
 CONSTRAINT [PK_Portfolios] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Section1]

-- %%
/****** Object:  Table [dbo].[Section1]    Script Date: 9.02.2021 11:42:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Section1](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[SubHeader] [nvarchar](max) NULL,
	[Header] [nvarchar](max) NULL,
	[WorkArea] [nvarchar](max) NULL,
	[PhotoUrl] [nvarchar](max) NULL,
 CONSTRAINT [PK_Section1] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SectionAbouts]

-- %%
/****** Object:  Table [dbo].[SectionAbouts]    Script Date: 9.02.2021 11:42:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SectionAbouts](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[PhotoUrl] [nvarchar](max) NULL,
	[Header] [nvarchar](max) NULL,
	[Description] [nvarchar](max) NULL,
 CONSTRAINT [PK_SectionAbouts] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SectionServices]

-- %%
/****** Object:  Table [dbo].[SectionServices]    Script Date: 9.02.2021 11:42:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SectionServices](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Header] [nvarchar](max) NULL,
	[Description] [nvarchar](max) NULL,
	[Icon] [nvarchar](max) NULL,
 CONSTRAINT [PK_SectionServices] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Testimonials]

-- %%
/****** Object:  Table [dbo].[Testimonials]    Script Date: 9.02.2021 11:42:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Testimonials](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[PhotoUrl] [nvarchar](max) NULL,
	[Fullname] [nvarchar](max) NULL,
	[WorkArea] [nvarchar](max) NULL,
	[Rating] [int] NOT NULL,
	[Description] [nvarchar](max) NULL,
 CONSTRAINT [PK_Testimonials] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [K102AgencyDB]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [K102AgencyDB] SET  READ_WRITE 
GO
